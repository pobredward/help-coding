# %% [markdown]
# # Solving the Taxi Problem using Q Learning

# %% [markdown]
# ### Goal:
#
# Say our agent is the driving the taxi. There are totally four locations and the agent has to
# pick up a passenger at one location and drop at the another. The agent will receive +20
# points as a reward for successful drop off and -1 point for every time step it takes. The agent
# will also lose -10 points for illegal pickups and drops. So the goal of our agent is to learn to
# pick up and drop passengers at the correct location in a short time without boarding any illegal
# passengers.

# %% [markdown]
#  First, we import all necessary libraries and simulate the environment

# %%
import random
import gym
env = gym.make('Taxi-v3')

# %% [markdown]
#  The environment is shown below, where the letters (R, G, Y, B) represents the different
# locations and a tiny yellow colored rectangle is the taxi driving by our agent.

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %% [markdown]
# Now, we initialize, Q table as a dictionary which stores state-action pair specifying value of performing an action a in
#  state s.

# %%
q = {}
for s in range(env.observation_space.n):
    for a in range(env.action_space.n):
        q[(s,a)] = 0.0

# %% [markdown]
# We define a function called update_q_table which will update the Q values according to our Q learning update rule.
#
# If you look at the below function, we take the value which has maximum value for a state-action pair and store it in a variable called qa, then we update the Q value of the preivous state by our update rule.

# %%
def update_q_table(prev_state, action, reward, nextstate, alpha, gamma):
    
    qa = max([q[(nextstate, a)] for a in range(env.action_space.n)])
    q[(prev_state,action)] += alpha * (reward + gamma * qa - q[(prev_state,action)])

# %% [markdown]
#
# Then, we define a function for performing epsilon-greedy policy. In epsilon-greedy policy, either we select best action with probability 1-epsilon or we explore new action with probability epsilon.

# %%
def epsilon_greedy_policy(state, epsilon):
    if random.uniform(0,1) < epsilon:
        return env.action_space.sample()
    else:
        return max(list(range(env.action_space.n)), key = lambda x: q[(state,x)])

# %% [markdown]
# Now we initialize necessary variables
#
# alpha - TD learning rate
#
# gamma - discount factor <br>
# epsilon - epsilon value in epsilon greedy policy

# %%
alpha = 0.4
gamma = 0.999
epsilon = 0.017

# %% [markdown]
# Now, Let us perform Q Learning!!!!

# %%
for i in range(2):
    
    r = 0
    iter = 0
    prev_state = env.reset()
    
    while True:
        
        
        env.render()
        
        print("=========================")
        
        # In each state, we select the action by epsilon-greedy policy
        action = epsilon_greedy_policy(prev_state, epsilon)
        
        print("action: ", action)
        
        # then we perform the action and move to the next state, and receive the reward
        nextstate, reward, done, _ = env.step(action)
        
        # Next we update the Q value using our update_q_table function
        # which updates the Q value by Q learning update rule
        
        update_q_table(prev_state, action, reward, nextstate, alpha, gamma)
        
        # Finally we update the previous state as next state
        prev_state = nextstate
        
       # print("next state: ", nextstate)
        
        # Store all the rewards obtained
        r += reward
        print("reward: ", reward)
            
        print("Cumulative reward: ", r)
        
        
        
        iter += 1
        print("iteration: ", iter)
        #we will break the loop, if we are at the terminal state of the episode
        if done:
            break
        
        
   
    env.render()
    print("total reward: ", r)
    print("==================================================================================")
    
env.close()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -1
# iteration:  1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -2
# iteration:  2
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -3
# iteration:  3
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -4
# iteration:  4
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -5
# iteration:  5
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -6
# iteration:  6
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -7
# iteration:  7
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -8
# iteration:  8
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -9
# iteration:  9
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -10
# iteration:  10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -11
# iteration:  11
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -12
# iteration:  12
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -13
# iteration:  13
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -14
# iteration:  14
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -15
# iteration:  15
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -16
# iteration:  16
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -17
# iteration:  17
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -18
# iteration:  18
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -19
# iteration:  19
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -20
# iteration:  20
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -21
# iteration:  21
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -31
# iteration:  22
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -41
# iteration:  23
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -42
# iteration:  24
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -43
# iteration:  25
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -44
# iteration:  26
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -45
# iteration:  27
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -55
# iteration:  28
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -65
# iteration:  29
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -66
# iteration:  30
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -67
# iteration:  31
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -68
# iteration:  32
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -69
# iteration:  33
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -79
# iteration:  34
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -89
# iteration:  35
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -90
# iteration:  36
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -91
# iteration:  37
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -92
# iteration:  38
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -93
# iteration:  39
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -103
# iteration:  40
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -113
# iteration:  41
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -114
# iteration:  42
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -115
# iteration:  43
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -116
# iteration:  44
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -117
# iteration:  45
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -118
# iteration:  46
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -119
# iteration:  47
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -120
# iteration:  48
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -121
# iteration:  49
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -122
# iteration:  50
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -123
# iteration:  51
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -1
# Cumulative reward:  -124
# iteration:  52
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -125
# iteration:  53
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -126
# iteration:  54
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -127
# iteration:  55
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -128
# iteration:  56
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -129
# iteration:  57
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -130
# iteration:  58
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -131
# iteration:  59
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -132
# iteration:  60
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -133
# iteration:  61
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -134
# iteration:  62
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -135
# iteration:  63
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -136
# iteration:  64
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -137
# iteration:  65
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -138
# iteration:  66
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -139
# iteration:  67
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -140
# iteration:  68
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -141
# iteration:  69
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -142
# iteration:  70
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -143
# iteration:  71
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -144
# iteration:  72
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -145
# iteration:  73
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -146
# iteration:  74
# +---------+
# |R: | :_:G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -147
# iteration:  75
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -157
# iteration:  76
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -1
# Cumulative reward:  -158
# iteration:  77
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -168
# iteration:  78
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -169
# iteration:  79
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -170
# iteration:  80
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -171
# iteration:  81
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -172
# iteration:  82
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -173
# iteration:  83
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -174
# iteration:  84
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -175
# iteration:  85
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -176
# iteration:  86
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -177
# iteration:  87
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -178
# iteration:  88
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -179
# iteration:  89
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -180
# iteration:  90
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -181
# iteration:  91
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -182
# iteration:  92
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -192
# iteration:  93
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -202
# iteration:  94
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -203
# iteration:  95
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -204
# iteration:  96
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -205
# iteration:  97
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -215
# iteration:  98
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -225
# iteration:  99
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -226
# iteration:  100
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -227
# iteration:  101
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -237
# iteration:  102
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -247
# iteration:  103
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -248
# iteration:  104
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -249
# iteration:  105
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -259
# iteration:  106
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -269
# iteration:  107
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -270
# iteration:  108
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -271
# iteration:  109
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -281
# iteration:  110
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -282
# iteration:  111
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -283
# iteration:  112
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -284
# iteration:  113
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -285
# iteration:  114
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -286
# iteration:  115
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -287
# iteration:  116
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -297
# iteration:  117
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -307
# iteration:  118
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -308
# iteration:  119
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -309
# iteration:  120
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -310
# iteration:  121
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -311
# iteration:  122
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -312
# iteration:  123
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -313
# iteration:  124
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -314
# iteration:  125
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -315
# iteration:  126
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -316
# iteration:  127
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -317
# iteration:  128
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -318
# iteration:  129
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -319
# iteration:  130
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -320
# iteration:  131
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -321
# iteration:  132
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -322
# iteration:  133
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -323
# iteration:  134
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -324
# iteration:  135
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -325
# iteration:  136
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -326
# iteration:  137
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -327
# iteration:  138
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -328
# iteration:  139
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -329
# iteration:  140
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -330
# iteration:  141
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -331
# iteration:  142
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -1
# Cumulative reward:  -332
# iteration:  143
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -333
# iteration:  144
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -334
# iteration:  145
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -335
# iteration:  146
# +---------+
# |R: | : :G|
# | : | :_: |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -336
# iteration:  147
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -346
# iteration:  148
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -356
# iteration:  149
# +---------+
# |R: | : :G|
# | : | : :_|
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -357
# iteration:  150
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -358
# iteration:  151
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -359
# iteration:  152
# +---------+
# |R: | : :G|
# | : | : : |
# | : : :_: |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -360
# iteration:  153
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -370
# iteration:  154
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -380
# iteration:  155
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : :_|
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -381
# iteration:  156
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -382
# iteration:  157
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -383
# iteration:  158
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : |_: |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -384
# iteration:  159
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -394
# iteration:  160
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -404
# iteration:  161
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | :_|
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -405
# iteration:  162
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -406
# iteration:  163
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -407
# iteration:  164
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -408
# iteration:  165
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -418
# iteration:  166
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -428
# iteration:  167
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -429
# iteration:  168
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B:_|
# +---------+
#   (South)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -430
# iteration:  169
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -431
# iteration:  170
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -441
# iteration:  171
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  20
# Cumulative reward:  -421
# iteration:  172
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# total reward:  -421
# ==================================================================================
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -1
# iteration:  1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -2
# iteration:  2
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -3
# iteration:  3
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -4
# iteration:  4
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -5
# iteration:  5
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -6
# iteration:  6
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -7
# iteration:  7
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -8
# iteration:  8
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -9
# iteration:  9
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -19
# iteration:  10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -29
# iteration:  11
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -30
# iteration:  12
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -31
# iteration:  13
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -32
# iteration:  14
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -33
# iteration:  15
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -34
# iteration:  16
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -35
# iteration:  17
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -36
# iteration:  18
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -46
# iteration:  19
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -47
# iteration:  20
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -48
# iteration:  21
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -58
# iteration:  22
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -68
# iteration:  23
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -69
# iteration:  24
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -70
# iteration:  25
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -71
# iteration:  26
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -72
# iteration:  27
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -82
# iteration:  28
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -92
# iteration:  29
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -93
# iteration:  30
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -94
# iteration:  31
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -95
# iteration:  32
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -105
# iteration:  33
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -115
# iteration:  34
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -116
# iteration:  35
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -117
# iteration:  36
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -118
# iteration:  37
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -119
# iteration:  38
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -120
# iteration:  39
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -121
# iteration:  40
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -122
# iteration:  41
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -123
# iteration:  42
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -124
# iteration:  43
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -125
# iteration:  44
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -126
# iteration:  45
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -127
# iteration:  46
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -128
# iteration:  47
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -129
# iteration:  48
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -130
# iteration:  49
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -131
# iteration:  50
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -132
# iteration:  51
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -133
# iteration:  52
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -134
# iteration:  53
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -135
# iteration:  54
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -136
# iteration:  55
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -137
# iteration:  56
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -138
# iteration:  57
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -139
# iteration:  58
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -140
# iteration:  59
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -141
# iteration:  60
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -142
# iteration:  61
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -143
# iteration:  62
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -144
# iteration:  63
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -154
# iteration:  64
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -164
# iteration:  65
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -165
# iteration:  66
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -166
# iteration:  67
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -167
# iteration:  68
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -168
# iteration:  69
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -169
# iteration:  70
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -170
# iteration:  71
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -171
# iteration:  72
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -172
# iteration:  73
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -173
# iteration:  74
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -174
# iteration:  75
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -175
# iteration:  76
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -176
# iteration:  77
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -177
# iteration:  78
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -187
# iteration:  79
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -188
# iteration:  80
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -189
# iteration:  81
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -190
# iteration:  82
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -191
# iteration:  83
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -192
# iteration:  84
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -193
# iteration:  85
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -194
# iteration:  86
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -195
# iteration:  87
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -196
# iteration:  88
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -197
# iteration:  89
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# ...
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -295
# iteration:  115
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -296
# iteration:  116
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -297
# iteration:  117
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -298
# iteration:  118
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -299
# iteration:  119
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -309
# iteration:  120
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -319
# iteration:  121
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -320
# iteration:  122
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -321
# iteration:  123
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -331
# iteration:  124
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -341
# iteration:  125
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -342
# iteration:  126
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -352
# iteration:  127
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -362
# iteration:  128
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -363
# iteration:  129
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -373
# iteration:  130
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -383
# iteration:  131
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -384
# iteration:  132
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -385
# iteration:  133
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -386
# iteration:  134
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -387
# iteration:  135
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -397
# iteration:  136
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -407
# iteration:  137
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -408
# iteration:  138
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -409
# iteration:  139
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -410
# iteration:  140
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -411
# iteration:  141
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -412
# iteration:  142
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -413
# iteration:  143
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -414
# iteration:  144
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -415
# iteration:  145
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -416
# iteration:  146
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -417
# iteration:  147
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -418
# iteration:  148
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -419
# iteration:  149
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -420
# iteration:  150
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -430
# iteration:  151
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -440
# iteration:  152
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -441
# iteration:  153
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -442
# iteration:  154
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -443
# iteration:  155
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -444
# iteration:  156
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -445
# iteration:  157
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -446
# iteration:  158
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -447
# iteration:  159
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -448
# iteration:  160
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -449
# iteration:  161
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -450
# iteration:  162
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -451
# iteration:  163
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -452
# iteration:  164
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -453
# iteration:  165
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -463
# iteration:  166
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -473
# iteration:  167
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -474
# iteration:  168
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -475
# iteration:  169
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -476
# iteration:  170
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -486
# iteration:  171
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -496
# iteration:  172
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -497
# iteration:  173
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -498
# iteration:  174
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -499
# iteration:  175
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  4
# reward:  -10
# Cumulative reward:  -509
# iteration:  176
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Pickup)
# =========================
# action:  5
# reward:  -10
# Cumulative reward:  -519
# iteration:  177
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -520
# iteration:  178
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -521
# iteration:  179
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -522
# iteration:  180
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -523
# iteration:  181
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -524
# iteration:  182
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -525
# iteration:  183
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -526
# iteration:  184
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -527
# iteration:  185
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -528
# iteration:  186
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -529
# iteration:  187
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  1
# reward:  -1
# Cumulative reward:  -530
# iteration:  188
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -531
# iteration:  189
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -532
# iteration:  190
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -533
# iteration:  191
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -534
# iteration:  192
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -535
# iteration:  193
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -536
# iteration:  194
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -537
# iteration:  195
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  0
# reward:  -1
# Cumulative reward:  -538
# iteration:  196
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -539
# iteration:  197
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  2
# reward:  -1
# Cumulative reward:  -540
# iteration:  198
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (East)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -541
# iteration:  199
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# =========================
# action:  3
# reward:  -1
# Cumulative reward:  -542
# iteration:  200
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (West)
# total reward:  -542
# ==================================================================================
